# %%
from chatterbot import ChatBot
bot = ChatBot(
    'A.U.R.A',
    logic_adapters=[
        'chatterbot.logic.BestMatch',
        ],
)
from chatterbot.trainers import ChatterBotCorpusTrainer
trainer = ChatterBotCorpusTrainer(bot)
trainer.train("chatterbot.corpus.english")
name=input("HI I am A.U.R.A whats yours")
print("Hi "+name+", How you doing")
while True:
    request=input(name+':')
    if request=='Bye' or request =='bye':
        break
    else:
        response=bot.get_response(request)
        # get_reponses() is a method of chatbot instance
        print('A.U.R.A:',response)

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ChatterBotCorpusTrainer
from flask import Flask, render_template, request

app = Flask(__name__)

botname='Normam'
chatbot = ChatBot(botname, 
	#storage_adapter='chatterbot.storage.SQLStorageAdapter',
	logic_adapters=[
        {
            'import_path': 'chatterbot.logic.BestMatch',
            'default_response': 'I am sorry, but I do not understand.',
            'maximum_similarity_threshold': 0.8
        },
        {
            "import_path": "chatterbot.logic.MathematicalEvaluation",

        },
        {
            "import_path": "chatterbot.logic.UnitConversion",

        },
        {
            "import_path": "profanity_adapter.ProfanityAdapter",

        },
        {
            "import_path": "covid19_adapter.Covid19Adapter",

        },
    ],
 )

@app.route("/")
def home():
    return render_template("index.html", botname=botname)

@app.route("/get")
def get_bot_response():
	userInput=request.args.get('msg')
	return str(chatbot.get_response(userInput))

if __name__ == '__main__':
	app.run(port=5500)
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\aravi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aravi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aravi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#  * Debug mode: off
#  * Running on http://127.0.0.1:5500/ (Press CTRL+C to quit)
# 127.0.0.1 - - [24/Jun/2021 23:40:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:40:31] "GET /static/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [24/Jun/2021 23:40:52] "GET /get?msg=hi%20normam HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:41:02] "GET /get?msg=I%20am%20sad HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:41:06] "GET /get?msg=you HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:41:09] "GET /get?msg=Ik HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:41:22] "GET /get?msg=I%20hope%20ur%20better%20that%20this HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:41:38] "GET /get?msg=So%20how%20r%20u%20 HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:41:45] "GET /get?msg=how%20are%20you HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:41:56] "GET /get?msg=Is%20internet%20a%20good%20place HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:42:52] "GET /get?msg=you%20are%20cruel HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:43:10] "GET /get?msg=you%20are%20cruel HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:43:36] "GET /get?msg=you%20are%20indecisive HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:43:49] "GET /get?msg=you%20are%20cruel HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:05] "GET /get?msg=you%20are%20an%20ass%20kisser HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:22] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:27] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:28] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:30] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:33] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:34] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:36] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:37] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:38] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:40] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:42] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:43] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:44] "GET /get?msg=you%20are%20schizophrenic HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:44:54] "GET /get?msg=you%20are%20busy HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:45:08] "GET /get?msg=you%27re%20right.%20%20it%20feels%20like%20my%20stomach%20after%20a%20bad%20night. HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:45:11] "GET /get?msg=you%27re%20right.%20%20it%20feels%20like%20my%20stomach%20after%20a%20bad%20night. HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:45:13] "GET /get?msg=you%27re%20right.%20%20it%20feels%20like%20my%20stomach%20after%20a%20bad%20night. HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:45:14] "GET /get?msg=you%27re%20right.%20%20it%20feels%20like%20my%20stomach%20after%20a%20bad%20night. HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:45:15] "GET /get?msg=you%27re%20right.%20%20it%20feels%20like%20my%20stomach%20after%20a%20bad%20night. HTTP/1.1" 200 -
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 9172 and this is thread id 9816.
# Exception closing connection <sqlite3.Connection object at 0x000002D306D0B300>
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 9172 and this is thread id 9816.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 342, in _close_connection
#     self._dialect.do_close(connection)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 492, in do_close
#     dbapi_connection.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 9172 and this is thread id 9816.
# 127.0.0.1 - - [24/Jun/2021 23:45:24] "GET /get?msg=you%20are%20avoiding HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:45:28] "GET /get?msg=you%20are%20avoiding HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:45:29] "GET /get?msg=you%20are%20avoiding HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:45:31] "GET /get?msg=you%20are%20avoiding HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:45:54] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:45:55] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 18732 and this is thread id 9652.
# Exception closing connection <sqlite3.Connection object at 0x000002D306D0B120>
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 18732 and this is thread id 9652.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 342, in _close_connection
#     self._dialect.do_close(connection)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 492, in do_close
#     dbapi_connection.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 18732 and this is thread id 9652.
# 127.0.0.1 - - [24/Jun/2021 23:45:56] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:45:57] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:45:59] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:00] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:00] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:02] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:05] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:10] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:12] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:12] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:13] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:15] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:15] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:16] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:16] "GET /get?msg=you%20are%20cheating HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:46:33] "GET /get?msg=you%20are%20the%20worst. HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:47:16] "GET /get?msg=you%20act%20like%20a%20child HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:47:38] "GET /get?msg=you%20act%20like%20a%20child HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:48:03] "GET /get?msg=hey HTTP/1.1" 200 -
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 15240 and this is thread id 10744.
# Exception closing connection <sqlite3.Connection object at 0x000002D37FB91D50>
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 15240 and this is thread id 10744.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 342, in _close_connection
#     self._dialect.do_close(connection)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 492, in do_close
#     dbapi_connection.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 15240 and this is thread id 10744.
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 17200 and this is thread id 10744.
# Exception closing connection <sqlite3.Connection object at 0x000002D306D0B030>
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 17200 and this is thread id 10744.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 342, in _close_connection
#     self._dialect.do_close(connection)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 492, in do_close
#     dbapi_connection.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 17200 and this is thread id 10744.
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 9652 and this is thread id 10744.
# Exception closing connection <sqlite3.Connection object at 0x000002D306D0B210>
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 9652 and this is thread id 10744.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 342, in _close_connection
#     self._dialect.do_close(connection)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 492, in do_close
#     dbapi_connection.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 9652 and this is thread id 10744.
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 10692 and this is thread id 10744.
# Exception closing connection <sqlite3.Connection object at 0x000002D306D0B3F0>
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 10692 and this is thread id 10744.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 342, in _close_connection
#     self._dialect.do_close(connection)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 492, in do_close
#     dbapi_connection.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 10692 and this is thread id 10744.
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 504 and this is thread id 10744.
# Exception closing connection <sqlite3.Connection object at 0x000002D306D0B300>
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 751, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 938, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 486, in do_rollback
#     dbapi_connection.rollback()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 504 and this is thread id 10744.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\pool.py", line 342, in _close_connection
#     self._dialect.do_close(connection)
#   File "C:\Users\aravi\anaconda3\envs\Chatbot\lib\site-packages\sqlalchemy\engine\default.py", line 492, in do_close
#     dbapi_connection.close()
# sqlite3.ProgrammingError: SQLite objects created in a thread can only be used in that same thread. The object was created in thread id 504 and this is thread id 10744.
# 127.0.0.1 - - [24/Jun/2021 23:48:14] "GET /get?msg=Hey HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Jun/2021 23:48:31] "GET /get?msg=How%20are%20you%20doing%3F HTTP/1.1" 200 -
